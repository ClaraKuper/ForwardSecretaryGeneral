# %%
## Wikipedia Scraping Notebook to retrieve resolutions mentioning the Secretary General of the United Nations
# by Clara Kuper
# April 2021

import requests
import time
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# all UN resolutions hosted on wikipedia
resolutions = range(1,2401)

# prepare a data table
columns = ['Resolution', 'Date', 'Subject', 'Mentions', 'WikiText', 'WikiLink']
SG_df = pd.DataFrame(columns = columns, index = np.arange(0,len(SG_list)))

row = 0

# loop thorugh all resolutions
# prevent a loop when this was already run
try: 
    print(SG_list)
except:
    SG_list = []
    for r in resolutions:
        # time.sleep(5)
        # load the wiki page as text
        x = requests.get('https://en.wikipedia.org/wiki/United_Nations_Security_Council_Resolution_{}'.format(r))        
        # parse to beautiful soup
        soup = BeautifulSoup(x.text, 'html')
        # find the main text
        main_text = soup.find('div',{'class': 'mw-parser-output'})
        try:
            infobox = main_text.find('table', {'class': 'infobox'})
            p = main_text.get_text(' ', strip=True)
            p = p[:p.find('[ edit ]')].strip()
            p = p[:p.find('References')].strip()
            # check if text contains "secretary general"
            SG_contained = 'Secretary-General' in p
            if SG_contained:
                
                # check the sentences where the SG is mentioned
                s = p.split('.')
                f = np.where(['Secretary-General' in s[i] for i in range(0,len(s))])
                
                # if it does, save the URL
                SG_list.append(x.url)
                
                infobox_info = infobox.find_all('td', {'class': 'infobox-data'})
                date = infobox_info[0].text
                subject = infobox_info[3].text
                if ('voted' in subject) or ('Adopted' in subject):
                    subject = infobox_info[2].text
                # and information from the website
                SG_df.loc[row, 'Resolution'] = x.url.split('_')[-1]
                SG_df.loc[row, 'Date'] = date
                SG_df.loc[row, 'Subject'] = subject
                SG_df.loc[row, 'Mentions']= s[f[0][0]:f[0][-1]+1]
                SG_df.loc[row, 'WikiLink'] = x.url
                SG_df.loc[row, 'WikiText'] = p
                
                
                # find the sentence that mentions the SG
                row += 1
                
            if r%100 == 0:
                print(r)
        except:
            pass

        
    # print the list of all URLs
    df = SG_df.dropna(thresh = 2)
    
    # assign topic ids
    topics = np.unique(df.Subject)
    df['topicID'] = np.nan
    df.loc[:,'topicID'] = [np.argwhere(topics == df.Subject[n])[0][0] for n in df.index]
    # How long is this list of URLS?
    print('We found {} entries mentioning the secretary-general'.format(len(SG_list)))
# Out:
# 970

# %%
# print the dataframe
df
# Out:
#     Resolution               Date  \
# 0           35     October 3 1947
# 1           44       April 1 1948
# 2           52       June 22 1948
# 3           54       July 15 1948
# 4           57  18 September 1948
# ..         ...                ...
# 956       2063       31 July 2012
# 957       2065  12 September 2012
# 958       2113       30 July 2013
# 959       2167       28 July 2014
# 960       2311     6 October 2016
#
#                                                Subject  \
# 0                              The Indonesian question
# 1                               The Palestine question
# 2                 Atomic Energy: International Control
# 3                               The Palestine Question
# 4                               The Palestine Question
# ..                                                 ...
# 956      Reports of the Secretary-General on the Sudan
# 957                      The situation in Sierra Leone
# 958      Reports of the Secretary-General on the Sudan
# 959  On enhancing the relationship between the Unit...
# 960  Recommendation regarding the appointment of th...
#
#                                               Mentions  \
# 0    [ 207 Code S/574 ( Document ) Subject The Indo...
# 1    [ 277 Code S/714, II ( Document ) Subject The ...
# 2    [ 325 Code S/852 ( Document ) Subject Atomic E...
# 3    [  The Resolution instructed the United Nation...
# 4    [ Shocked by the death of Count Folke Bernadot...
# ..                                                 ...
# 956  [ 6,819 Code S/RES/2063 ( Document ) Subject R...
# 957  [  It also asked UNIPSIL to assist conflict-pr...
# 958  [ 7013 Code S/RES/2113 ( Document ) Subject Re...
# 959  [ The resolution originated through a debate i...
# 960  [ 7,782 Code S/RES/2311 ( Document ) Subject R...
#
#                                               WikiText  \
# 0    UN Security Council Resolution 35 Date October...
# 1    UN Security Council Resolution 44 Date April 1...
# 2    UN Security Council Resolution 52 Date June 22...
# 3    UN Security Council Resolution 54 Date July 15...
# 4    UN Security Council Resolution 57 Folke Bernad...
# ..                                                 ...
# 956  UN Security Council Resolution 2063 Map of Dar...
# 957  UN Security Council Resolution 2065 Street in ...
# 958  UN Security Council Resolution 2113 Date 30 Ju...
# 959  UN Security Council Resolution 2167 UN Securit...
# 960  UN Security Council Resolution 2311 António Gu...
#
#                                               WikiLink
# 0    https://en.wikipedia.org/wiki/United_Nations_S...
# 1    https://en.wikipedia.org/wiki/United_Nations_S...
# 2    https://en.wikipedia.org/wiki/United_Nations_S...
# 3    https://en.wikipedia.org/wiki/United_Nations_S...
# 4    https://en.wikipedia.org/wiki/United_Nations_S...
# ..                                                 ...
# 956  https://en.wikipedia.org/wiki/United_Nations_S...
# 957  https://en.wikipedia.org/wiki/United_Nations_S...
# 958  https://en.wikipedia.org/wiki/United_Nations_S...
# 959  https://en.wikipedia.org/wiki/United_Nations_S...
# 960  https://en.wikipedia.org/wiki/United_Nations_S...
#
# [961 rows x 6 columns]

# %%
# save the dataframe
df.to_csv('SG_list.csv', index = False)
# Out:
# C:\Users\ClaraQ\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ClaraQ\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# s = p.split('.')
# f = np.where(['Secretary-General' in s[i] for i in range(0,len(s))])
# s[f[0][0]:f[0][-1]+1]

# %%
# Out:
# '\xa0China\xa0France\xa0Russia\xa0United Kingdom\xa0United States'

# %%
# Out:
# '18 September 1948'
